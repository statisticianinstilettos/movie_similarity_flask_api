# %%
import requests
import pandas as pd

# %% [markdown]
# # Example Curl Request

# %%
movies = pd.read_csv('data/movie_demographics.csv', index_col='movieId')
movies.head()
# Out:
#                                                      title  \
# movieId
# 0                                           Jumanji (1995)
# 1        City of Lost Children, The (Cité des enfants p...
# 2                Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3                              Seven (a.k.a. Se7en) (1995)
# 4                               Usual Suspects, The (1995)
#
#                                          genres  ratings_count  avg_rating
# movieId
# 0                    Adventure|Children|Fantasy          22243    3.211977
# 1        Adventure|Drama|Fantasy|Mystery|Sci-Fi           8520    3.952230
# 2                       Mystery|Sci-Fi|Thriller          44980    3.898055
# 3                              Mystery|Thriller          43249    4.053493
# 4                        Crime|Mystery|Thriller          47006    4.334372

# %%
def lookup_movie_id_by_title(movie_title):
    return movies[movies.title.str.contains(movie_title)]

# %%
lookup_movie_id_by_title("Dirty Dancing")
# Out:
#                                        title                 genres  \
# movieId
# 1957                    Dirty Dancing (1987)  Drama|Musical|Romance
# 7877     Dirty Dancing: Havana Nights (2004)                Romance
#
#          ratings_count  avg_rating
# movieId
# 1957             11013    3.209207
# 7877               431    2.977958

# %%
url = 'http://127.0.0.1:5000/'
payload ={'movie_title': 'Lord of the Rings: The Fellowship of the Ring, The (2001)'}
payload ={'movie_title': 'Zodiac (2007)'}
payload ={'movie_title': 'Grease (1978)'}
#payload ={'movie_title': 'Dirty Dancing (1987)'}
#payload ={'movie_title': 'Aladdin (1992)'}
response = requests.get(url, payload)
pd.DataFrame(response.json()).T
# Out:
#      avg_rating                           genres similarity_score  \
# 2091        3.4             Comedy|Drama|Romance         0.718062
# 4146          2           Comedy|Musical|Romance         0.698277
# 4226        3.5                    Drama|Romance         0.678981
# 1201        3.9             Comedy|Drama|Romance         0.674457
# 1199        3.6                   Comedy|Romance         0.650825
# 1944        3.5             Comedy|Drama|Musical          0.64858
# 3962        3.3             Comedy|Drama|Romance          0.61107
# 733         3.3            Comedy|Fantasy|Sci-Fi         0.606247
# 272         3.8                   Comedy|Romance         0.598992
# 42          3.9                            Drama          0.59627
# 416         3.7  Children|Comedy|Fantasy|Musical         0.593332
# 265         3.8            Action|Comedy|Musical          0.59066
# 2684        3.8            Drama|Musical|Romance         0.587867
# 93          3.9                           Comedy         0.585183
# 1903        3.6       Comedy|Crime|Drama|Musical         0.584361
# 2314        3.1                   Comedy|Romance         0.583555
# 479           3                           Comedy         0.583237
# 603         3.6            Drama|Musical|Romance         0.582341
# 1650        3.8                     Comedy|Drama         0.578271
# 2906        2.7                   Comedy|Romance         0.577985
#
#                                               title
# 2091                          Pretty in Pink (1986)
# 4146                                Grease 2 (1982)
# 4226                  Some Kind of Wonderful (1987)
# 1201                         Say Anything... (1989)
# 1199                         Sixteen Candles (1984)
# 1944                               Hairspray (2007)
# 3962                    Saturday Night Fever (1977)
# 733                            Weird Science (1985)
# 272                       Better Off Dead... (1985)
# 42                        Dead Poets Society (1989)
# 416                             Mary Poppins (1964)
# 265                      Blues Brothers, The (1980)
# 2684                         King and I, The (1956)
# 93                  Ferris Bueller's Day Off (1986)
# 1903                                 Chicago (2002)
# 2314                       Never Been Kissed (1999)
# 479   Romy and Michele's High School Reunion (1997)
# 603                             Moulin Rouge (2001)
# 1650                     Breakfast Club, The (1985)
# 2906                      Look Who's Talking (1989)

# %%
# !curl -X GET http://127.0.0.1:5000/ -d movie_title='Zodiac (2007)'
# Out:
# {"3508": {"title": "American Gangster (2007)", "genres": "Crime|Drama|Thriller", "avg_rating": 3.8, "similarity_score": 0.7392183931380412}, "3027": {"title": "Bank Job, The (2008)", "genres": "Action|Crime|Thriller", "avg_rating": 3.6, "similarity_score": 0.7146542104854654}, "6819": {"title": "Memories of Murder (Salinui chueok) (2003)", "genres": "Crime|Drama|Mystery|Thriller", "avg_rating": 4.0, "similarity_score": 0.6977241029819163}, "1304": {"title": "Changeling (2008)", "genres": "Crime|Drama|Mystery", "avg_rating": 3.7, "similarity_score": 0.6966547567454386}, "15326": {"title": "Ted Bundy (2002)", "genres": "Crime|Drama|Thriller", "avg_rating": 2.7, "similarity_score": 0.6892827952069682}, "3016": {"title": "Munich (2005)", "genres": "Action|Crime|Drama|Thriller", "avg_rating": 3.7, "similarity_score": 0.6888754240403957}, "3021": {"title": "Mr. Brooks (2007)", "genres": "Crime|Drama|Thriller", "avg_rating": 3.7, "similarity_score": 0.6842791604618743}, "4162": {"title": "United 93 (2006)", "genres": "Crime|Drama", "avg_rating": 3.6, "similarity_score": 0.67201337163884}, "1802": {"title": "21 (2008)", "genres": "Crime|Drama|Romance|Thriller", "avg_rating": 3.5, "similarity_score": 0.6672512238746249}, "6112": {"title": "Perfume: The Story of a Murderer (2006)", "genres": "Crime|Drama|Thriller", "avg_rating": 3.7, "similarity_score": 0.6657600352963517}, "2771": {"title": "Frost/Nixon (2008)", "genres": "Drama", "avg_rating": 3.8, "similarity_score": 0.6648870297412255}, "965": {"title": "Grindhouse (2007)", "genres": "Action|Crime|Horror|Sci-Fi|Thriller", "avg_rating": 3.7, "similarity_score": 0.6628592792582265}, "2778": {"title": "Public Enemies (2009)", "genres": "Crime|Drama|Thriller", "avg_rating": 3.3, "similarity_score": 0.6611834761330377}, "2797": {"title": "Social Network, The (2010)", "genres": "Drama", "avg_rating": 3.8, "similarity_score": 0.6593159394911412}, "5180": {"title": "Diving Bell and the Butterfly, The (Scaphandre et le papillon, Le) (2007)", "genres": "Drama", "avg_rating": 3.9, "similarity_score": 0.6589218196645444}, "1836": {"title": "127 Hours (2010)", "genres": "Adventure|Drama|Thriller", "avg_rating": 3.7, "similarity_score": 0.6564154249483547}, "4835": {"title": "Pursuit of Happyness, The (2006)", "genres": "Drama", "avg_rating": 3.8, "similarity_score": 0.6557722607080672}, "1952": {"title": "Into the Wild (2007)", "genres": "Action|Adventure|Drama", "avg_rating": 4.0, "similarity_score": 0.6540601943425051}, "5529": {"title": "Breach (2007)", "genres": "Drama|Thriller", "avg_rating": 3.6, "similarity_score": 0.6500146561032387}, "5248": {"title": "You Don't Know Jack (2010)", "genres": "Drama", "avg_rating": 3.6, "similarity_score": 0.6457896052508896}}
