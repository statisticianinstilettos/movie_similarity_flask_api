# %%
import requests
import pandas as pd

# %% [markdown]
# # Example Curl Request

# %%
movies = pd.read_csv('data/movie_demographics.csv', index_col='movieId')
movies.head()
# Out:
#                                                      title  \
# movieId
# 0                                           Jumanji (1995)
# 1        City of Lost Children, The (Cité des enfants p...
# 2                Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3                              Seven (a.k.a. Se7en) (1995)
# 4                               Usual Suspects, The (1995)
#
#                                          genres  ratings_count  avg_rating
# movieId
# 0                    Adventure|Children|Fantasy          22243    3.211977
# 1        Adventure|Drama|Fantasy|Mystery|Sci-Fi           8520    3.952230
# 2                       Mystery|Sci-Fi|Thriller          44980    3.898055
# 3                              Mystery|Thriller          43249    4.053493
# 4                        Crime|Mystery|Thriller          47006    4.334372

# %%
def lookup_movie_id_by_title(movie_title):
    return movies[movies.title.str.contains(movie_title)]

# %%
lookup_movie_id_by_title("")
# Out:
#                                                      title  \
# movieId
# 0                                           Jumanji (1995)
# 1        City of Lost Children, The (Cité des enfants p...
# 2                Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3                              Seven (a.k.a. Se7en) (1995)
# 4                               Usual Suspects, The (1995)
# 5               Rumble in the Bronx (Hont faan kui) (1995)
# 6                                           Rob Roy (1995)
# 7                                            Clerks (1994)
# 8        Interview with the Vampire: The Vampire Chroni...
# 9                Star Wars: Episode IV - A New Hope (1977)
# 10       Léon: The Professional (a.k.a. The Professiona...
# 11                                     Pulp Fiction (1994)
# 12                        Shawshank Redemption, The (1994)
# 13                      What's Eating Gilbert Grape (1993)
# 14                                        Mask, The (1994)
# ...

# %%
url = 'http://127.0.0.1:5000/'
payload ={'movie_title': 'Lord of the Rings: The Fellowship of the Ring, The (2001)'}
#payload ={'movie_title': 'Zodiac (2007)'}
#payload ={'movie_title': 'Grease (1978)'}
#payload ={'movie_title': 'Dirty Dancing (1987)'}
#payload ={'movie_title': 'Aladdin (1992)'}
#payload ={'movie_title': 'Moon (2009)'}
payload ={'movie_title': 'Queen of the Damned (2002)'}
response = requests.get(url, payload)
pd.DataFrame(response.json()).T
# Out:
#       avg_rating                                         genres  \
# 672         2.56                                         Horror
# 3888        3.19                   Action|Drama|Horror|Thriller
# 834         2.75                          Action|Fantasy|Sci-Fi
# 8141        3.11                        Adventure|Comedy|Horror
# 3748         2.5                                  Comedy|Horror
# 165          2.8                Action|Adventure|Fantasy|Horror
# 6439        3.39  Action|Fantasy|Horror|Mystery|Sci-Fi|Thriller
# 1770        2.97                 Action|Fantasy|Horror|Thriller
# 716         3.43                Fantasy|Horror|Romance|Thriller
# 8965        2.86                         Action|Horror|Thriller
# 2482        2.59                                         Horror
# 8975         1.8                                Horror|Thriller
# 1744        3.14                         Action|Horror|Thriller
# 5878        1.67                                 Action|Fantasy
# ...

# %%
# !curl -X GET http://127.0.0.1:5000/ -d movie_title='Zodiac (2007)'
# Out:
# {"6112": {"genres": "Crime|Drama|Thriller", "avg_rating": 3.67, "similarity_score": 0.6658, "title": "Perfume: The Story of a Murderer (2006)"}, "1952": {"genres": "Action|Adventure|Drama", "avg_rating": 3.97, "similarity_score": 0.654, "title": "Into the Wild (2007)"}, "4162": {"genres": "Crime|Drama", "avg_rating": 3.65, "similarity_score": 0.672, "title": "United 93 (2006)"}, "6819": {"genres": "Crime|Drama|Mystery|Thriller", "avg_rating": 3.98, "similarity_score": 0.6977, "title": "Memories of Murder (Salinui chueok) (2003)"}, "965": {"genres": "Action|Crime|Horror|Sci-Fi|Thriller", "avg_rating": 3.72, "similarity_score": 0.6628, "title": "Grindhouse (2007)"}, "3016": {"genres": "Action|Crime|Drama|Thriller", "avg_rating": 3.73, "similarity_score": 0.6888, "title": "Munich (2005)"}, "1802": {"genres": "Crime|Drama|Romance|Thriller", "avg_rating": 3.48, "similarity_score": 0.6672, "title": "21 (2008)"}, "1836": {"genres": "Adventure|Drama|Thriller", "avg_rating": 3.74, "similarity
# ...
